# %%
import pandas 
import numpy as np
import math

# %%
##player stats
df = pandas.read_csv('../data/20192020data.csv')
dfteams = pandas.read_csv('../data/teams20192020.csv',delimiter = '\t')
aggdict = dict()
for item in df.items():
    #print(item[0])
    if item[0] == 'Rk' or item[0] == 'S%' or item[0] == 'FO%':
        print("ok")
        aggdict[item[0]] = 'mean'
    else:
        aggdict[item[0]] = 'sum'
print(aggdict)
clean = df.groupby(['Player']).agg(aggdict) 
stored = 0

lastnames = []
firstnames = []
for i in clean.iterrows():
    #print(i[0])
    first = ""
    last = ""
    f = True
    for letter in i[0]:
        if letter == "\\" :
            break
        if letter == " ":
            f = False
            continue
        if f:
            first = first +letter
        else:
            last += letter
    #print(last,first)
    lastnames.append(last)
    firstnames.append(first)
clean['First'] = firstnames
clean['Last'] = lastnames

clean = clean.sort_values(['Last'])
clean = clean.drop('Rk', 1)
clean.columns.name = df.index.name
clean.index.name = None

clean.reset_index(drop=True, inplace=True)
clean = clean.drop('Player', 1)
clean #HERE IS FINAL 
## RIGHT NOW I STILL NEED TO Adress the Team and the position being weird, but that should be easy
# Out:
# ok
# ok
# ok
# {'Rk': 'mean', 'Player': 'sum', 'Age': 'sum', 'Tm': 'sum', 'Pos': 'sum', 'GP': 'sum', 'G': 'sum', 'A': 'sum', 'PTS': 'sum', '+/-': 'sum', 'PIM': 'sum', 'PS': 'sum', 'EV': 'sum', 'PP': 'sum', 'SH': 'sum', 'GW': 'sum', 'EV.1': 'sum', 'PP.1': 'sum', 'SH.1': 'sum', 'S': 'sum', 'S%': 'mean', 'TOI': 'sum', 'ATOI': 'sum', 'BLK': 'sum', 'HIT': 'sum', 'FOW': 'sum', 'FOL': 'sum', 'FO%': 'mean'}
#      Age         Tm     Pos   GP   G   A  PTS  +/-  PIM   PS  ...         S%  \
# 0     32        DET      LW   49   0   3    3  -14   25 -0.9  ...   0.000000
# 1     26        TOR      LW    5   0   1    1    0    0  0.0  ...   0.000000
# 2     21        OTT      RW    2   1   0    1    0    2  0.2  ...  33.300000
# 3     28        FLA       C   66  20   7   27    2   21  2.9  ...  18.500000
# 4     87  TOTPITANA  LWLWLW   44   2   4    6    6    8  0.5  ...  20.000000
# ..   ...        ...     ...  ...  ..  ..  ...  ...  ...  ...  ...        ...
# 878   24        VEG      LW   15   1   3    4   -2    6  0.1  ...   5.300000
# 879   28        CHI       D   29   1   5    6   10   10  1.9  ...   2.400000
# 880   72  TOTSTLDET  LWLWLW  100   4  14   18    4   20  0.8  ...   4.733333
# 881   30        PHI      LW   66  19  21   40    5    8  4.5  ...  12.600000
# 882   28        CAR       D   49   1   7    8   -7   10  1.0  ...   1.700000
#
#       TOI             ATOI  BLK  HIT  FOW  FOL        FO%     First  \
# 0     565            11:32   26  103   38   31  55.100000    Justin
# 1      44             8:42    1    1    0    0        NaN    Pontus
# 2      12             5:47    0    0    0    0        NaN    Vitaly
# 3    1054            15:58  103  121  381  414  47.900000      Noel
# 4     324     7:216:369:56   14   50   76   74  50.500000    Andrew
# ..    ...              ...  ...  ...  ...  ...        ...       ...
# 878   183            12:13    3   20    0    1   0.000000  Valentin
# 879   577            19:55   73   93    0    0        NaN    Calvin
# 880  1073  10:4310:0112:13   32  240  236  312  43.066667     Jacob
# 881   983            14:54   18   25    8   15  34.800000     James
# 882   728            14:52   37   21    0    0        NaN    Trevor
#
#             Last
# 0     Abdelkader
# 1          Aberg
# 2        Abramov
# 3        Acciari
# 4       Agozzino
# ..           ...
# 878        Zykov
# 879       deHaan
# 880     deLaRose
# 881  vanRiemsdyk
# 882  vanRiemsdyk
#
# [883 rows x 28 columns]

# %%
##team stats
dfteams
# Out:
#                      Name  GP   W   L  OL  PTS   PTS%   GF   GA   SRS   SOS  \
