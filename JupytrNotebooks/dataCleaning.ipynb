# %%
import pandas 
import numpy as np
import math

# %%
##player stats
abrvs = ['BOS','WSH','TBL','PHI','PIT','CAR','TOR','CBJ','NYI','NYR','FLA','MTL','BUF','NJD','OTT','DET','STL','VEG','COL','EDM','DAL','WPG','CGY','VAN','NSH','MIN','ARI','CHI','ANA','LAK','SJS']

df = pandas.read_csv('../data/20192020data.csv')
print("NORMAL SIZE:", df.shape)
dfadv = pandas.read_csv('../data/advanced20192020.csv')
print("ADVANCED SIDE:", dfadv.shape)
dfadvtm = pandas.read_csv('../data/advancedteam20192020.csv')
print("ADVANCED TEAM SIZE:", dfadvtm.shape)
dfadv = dfadv.drop(columns=['Rk', 'Age', 'Pos', 'GP', 'TOI/60'])
#dfadv.sort_values(by=['Player'])
dfadvtm = dfadvtm.drop(columns=['S%', 'SV%'])
#for column in dfadv.columns:
#    df[column] = dfadv[column]
#pandas.concat([df,dfadv], axis=1)
dfteams = pandas.read_csv('../data/teams20192020.csv',delimiter = '\t')
print("TEAM SIZE:", dfteams.shape)
for column in dfadvtm.columns:
    dfteams[column] = dfadvtm[column]
aggdict = dict()
for item in df.items():
    #print(item[0])
    if item[0] == 'Rk' or item[0] == 'S%' or item[0] == 'FO%':
        #print("ok")
        aggdict[item[0]] = 'mean'
    else:
        aggdict[item[0]] = 'sum'
clean = df.groupby(['Player']).agg(aggdict) 

#clean = df
stored = 0

lastnames = []
firstnames = []

for i in clean.iterrows():
    #print(i[0])
    first = ""
    last = ""
    f = True
    for letter in i[0]:
        if letter == "\\" :
            break
        if letter == " ":
            f = False
            continue
        if f:
            first = first +letter
        else:
            last += letter
    #print(last,first)
    lastnames.append(last)
    firstnames.append(first)
clean['First'] = firstnames
clean['Last'] = lastnames

#clean = clean.sort_values(['Last'])
clean = clean.drop('Rk', 1)
#clean.columns.name = df.index.name
#clean.index.name = None


#clean = clean.drop('Player', 1)
a = clean['Tm'].unique().tolist()
A = [abv for abv in a if len(abv)<=3]
#print(A)
## RIGHT NOW I STILL NEED TO Adress the Team and the position being weird, but that should be easy
#clean.head(50)
clean = clean[clean['Tm'].isin(abrvs)]
dfadv = dfadv[dfadv['Tm'].isin(abrvs)]
dfadv = dfadv.sort_values(by=['Player'])
dfadv = dfadv.drop(columns=['Player', 'Tm'])
dfadv.reset_index(drop=True, inplace=True)
clean.reset_index(drop=True, inplace=True)
clean = pandas.concat([clean, dfadv], axis=1)
clean
# Out:
# NORMAL SIZE: (1016, 28)
# ADVANCED SIDE: (883, 26)
# ADVANCED TEAM SIZE: (31, 26)
# TEAM SIZE: (31, 15)
#                            Player  Age   Tm Pos  GP   G   A  PTS  +/-  PIM  \
# 0          Aaron Ekblad\ekblaaa01   23  FLA   D  67   5  36   41   12   26
# 1             Aaron Ness\nessaa01   29  ARI   D  24   0   1    1    1    0
# 2          Adam Boqvist\boqviad01   19  CHI   D  41   4   9   13   -3    6
# 3           Adam Brooks\brookad01   23  TOR   C   7   0   3    3    1    0
# 4              Adam Erne\ernead01   24  DET  LW  56   2   3    5  -24   28
# 5                Adam Fox\foxad01   21  NYR   D  70   8  34   42   22   32
# 6         Adam Gaudette\gaudead01   23  VAN   C  59  12  21   33   -7   37
# 7         Adam Henrique\henriad01   29  ANA   C  71  26  17   43   -3   22
# 8          Adam Johnson\johnsad01   25  PIT   C   7   1   1    2   -1    2
# 9          Adam Larsson\larssad01   27  EDM   D  49   1   5    6    0   35
# 10           Adam Lowry\lowryad01   26  WPG  LW  49   4   6   10   -4   23
# 11          Adam Pelech\pelecad01   25  NYI   D  38   1   8    9    4   20
# 12         Adrian Kempe\kempead01   23  LAK  LW  69  11  21   32  -10   29
# 13           Alan Quine\quineal01   26  CGY   C   9   1   0    1   -1    4
# 14    Aleksander Barkov\barkoal01   24  FLA   C  66  20  42   62    2   18
# 15       Aleksi Saarela\saareal01   23  FLA   C   9   2   2    4    2    0
# 16           Alex Biega\biegaal01   31  DET   D  49   0   3    3   -9   24
# 17        Alex Chiasson\chiasal01   29  EDM  RW  65  11  13   24   -3   42
# 18       Alex DeBrincat\debrial01   22  CHI  RW  70  18  27   45  -10   15
# 19       Alex Goligoski\goligal01   34  ARI   D  70   4  28   32    8   24
# 20         Alex Iafallo\iafalal01   26  LAK   C  70  17  26   43    1   14
# 21         Alex Killorn\killoal01   30  TBL   C  68  26  23   49   19   20
# 22        Alex Ovechkin\ovechal01   34  WSH  LW  68  48  19   67  -12   30
# 23     Alex Pietrangelo\pietral01   30  STL   D  70  16  36   52   11   20
# 24           Alex Steen\steenal01   35  STL   C  55   7  10   17    7   12
# 25             Alex Tuch\tuchal01   23  VEG  RW  42   8   9   17  -10    8
# 26      Alexander Edler\edleral01   33  VAN   D  59   5  28   33   13   62
# 27    Alexander Kerfoot\kerfoal01   25  TOR   C  65   9  19   28   -2   32
# 28   Alexander Nylander\nylanal01   21  CHI  LW  65  10  16   26   -2   10
# 29    Alexander Radulov\radulal01   33  DAL  RW  60  15  19   34    8   46
# ..                            ...  ...  ...  ..  ..  ..  ..  ...  ...  ...
# 788   Vinnie Hinostroza\hinosvi01   25  ARI   C  68   5  17   22    1   14
# 789      Vitaly Abramov\abramvi01   21  OTT  RW   2   1   0    1    0    2
# 790    Vladimir Sobotka\sobotvl01   32  BUF   C  16   1   2    3    2    4
# 791  Vladimir Tarasenko\tarasvl01   28  STL  RW  10   3   7   10   -2    0
# 792  Vladislav Gavrikov\gavrivl01   24  CBJ   D  69   5  13   18    1   18
# 793   Vladislav Kamenev\kamenvl01   23  COL  LW  38   1   7    8   -2    8
# 794      Warren Foegele\foegewa01   23  CAR  LW  68  13  17   30    9   34
# 795        Will Butcher\butchwi01   25  NJD   D  56   4  17   21   -8    6
# 796     William Carrier\carriwi01   25  VEG  LW  71   7  12   19    0   39
# 797    William Karlsson\karlswi01   27  VEG   C  63  15  31   46   11   16
# 798    William Lagesson\lageswi01   23  EDM   D   8   0   0    0   -4    0
# 799    William Nylander\nylanwi01   23  TOR   C  68  31  28   59   -2   12
# 800      Xavier Ouellet\ouellxa01   26  MTL   D  12   0   2    2    0    4
# 801        Yakov Trenin\treniya01   23  NSH   C  21   2   4    6    1    9
# 802        Yanni Gourde\gourdya01   28  TBL   C  70  10  20   30   -5   49
# 803       Yannick Weber\weberya01   31  NSH   D  41   1   2    3   -1   14
# 804         Zac Rinaldo\rinalza01   29  CGY   C  19   3   2    5   -1   34
# 805    Zach Aston-Reese\astonza01   25  PIT   C  57   6   7   13    6   28
# 806          Zach Hyman\hymanza01   27  TOR   C  51  21  16   37   13   23
# 807         Zach Parise\parisza01   35  MIN  LW  69  25  21   46  -11    8
# 808        Zach Sanford\sanfoza01   25  STL  LW  58  16  14   30   13   28
# 809        Zach Trotman\trotmza01   29  PIT   D   8   0   0    0   -1    4
# 810       Zach Werenski\werenza01   22  CBJ   D  63  20  21   41    9   10
# 811     Zach Whitecloud\whiteza01   23  VEG   D  16   0   1    1    3    4
# 812    Zachary Senyshyn\senysza01   22  BOS  RW   4   0   2    2    1    0
# 813        Zack Kassian\kassiza01   29  EDM  RW  59  15  19   34    0   69
# 814        Zack MacEwen\macewza01   23  VAN   C  17   5   1    6    6   20
# 815          Zack Smith\smithza01   31  CHI   C  50   4   7   11    2   29
# 816         Zdeno Chara\charazd01   42  BOS   D  68   5   9   14   26   60
# 817   Zemgus Girgensons\girgeze01   26  BUF   C  69  12   7   19   -1   10
#
#      ...  oiSV%    PDO  oZS%  dZS%  TOI(EV)  TK  GV  E+/-  SAtt.  Thru%
# 0    ...   90.0  100.8  48.7  51.3    19:11  37  74  -1.1    265   55.5
# 1    ...   90.8   99.6  55.6  44.4    12:00   1   8   1.2     27   40.7
# 2    ...   91.0  100.2  58.4  41.6    13:53  10  26  -2.8    107   46.7
# 3    ...   89.5  105.3  45.8  54.2     7:24   2   1   0.3      5   40.0
# 4    ...   89.1   93.9  44.9  55.1    10:50   5  27  -2.3    106   59.4
# 5    ...   91.6  103.0  53.9  46.1    16:44  57  61   7.6    243   51.4
# 6    ...   90.7  101.1  59.6  40.4    10:42  23  15  -8.2    151   49.7
# 7    ...   89.3   98.9  50.0  50.0    13:38  26  32  -0.5    281   60.5
# 8    ...   85.0  100.8  24.0  76.0     6:39   1   1   0.8      6   83.3
# 9    ...   91.8  100.6  44.3  55.7    17:50  16  35  -3.8    127   48.0
# 10   ...   93.3   99.2  38.6  61.4    12:30  31  11  -7.2    112   60.7
# 11   ...   91.6  101.1  37.9  62.1    18:09  32  48  -3.7    115   42.6
# 12   ...   89.9   95.1  52.5  47.5    12:35  24  27   4.1    262   56.5
# 13   ...   94.6   97.3  54.5  45.5     9:47   2   1  -0.2     18   66.7
# 14   ...   89.8   99.7  57.5  42.5    15:19  51  52   3.2    267   64.4
# 15   ...   94.8  102.5  49.0  51.0    11:14   6   3  -1.3     24   62.5
# 16   ...   93.3   98.6  47.5  52.5    14:25   4  30  -8.0    123   44.7
# 17   ...   94.4  101.2  50.9  49.1    10:48  14  20  -0.5    158   61.4
# 18   ...   91.4   99.5  58.3  41.7    13:55  41  37  -3.1    363   57.0
# 19   ...   91.9  100.6  49.1  50.9    18:28   7  53  -2.0    213   47.4
# 20   ...   90.1   99.4  50.3  49.7    14:59  18  11  -1.3    231   61.5
# 21   ...   92.6  105.0  48.0  52.0    12:55  27  26   1.2    209   62.2
# 22   ...   87.9   99.1  53.6  46.4    15:39  28  48   2.1    561   55.4
# 23   ...   89.7  100.3  51.6  48.4    18:56  43  45   4.6    418   53.8
# 24   ...   90.9  101.9  47.7  52.3    11:18  16  12   1.8    115   61.7
# 25   ...   88.8   95.7  60.3  39.7    12:42  27  27   3.0    170   58.2
# 26   ...   91.5  101.5  42.9  57.1    18:17   9  43  -1.1    259   45.6
# 27   ...   88.6   99.1  48.3  51.7    13:04  28  33  -3.5    152   57.9
# 28   ...   91.8   99.9  46.1  53.9    10:57  25  23  -1.6    151   62.3
# 29   ...   94.1  101.8  61.3  38.7    14:04  26  44   8.7    218   60.6
# ..   ...    ...    ...   ...   ...      ...  ..  ..   ...    ...    ...
# 788  ...   92.8   99.7  42.5  57.5    12:03  30  20  -2.8    209   63.2
# 789  ...   87.5  104.2  33.3  66.7     5:47   0   1  -0.3      4   75.0
# 790  ...   94.3  104.1  39.8  60.2    12:36   3   3  -2.3     32   71.9
# 791  ...   86.2   97.6  58.7  41.3    13:43   3   5   0.5     47   55.3
# 792  ...   92.1   99.6  41.7  58.3    17:10  16  33   6.1    159   50.9
# 793  ...   91.5   97.3  52.5  47.5     7:42  18   7  -1.1     64   50.0
# 794  ...   91.3  100.0  49.2  50.8    12:30  39  30   8.7    208   62.0
# 795  ...   90.4   99.1  55.0  45.0    16:06  10  27  -1.6    148   41.9
# 796  ...   91.5   99.1  58.0  42.0     9:44  22   8   9.1    158   62.7
# 797  ...   90.9   99.7  55.0  45.0    14:57  54  37  10.9    251   55.0
# 798  ...   87.0   91.8  46.3  53.7    10:31   0   7  -0.5     19   42.1
# 799  ...   89.4   98.8  60.4  39.6    15:08  42  41   6.5    295   66.8
# 800  ...   90.9  100.6  53.5  46.5    12:52   1   4   0.6     28   28.6
# 801  ...   90.2  100.2  42.2  57.8     9:42   7   3  -0.1     45   55.6
# 802  ...   89.9   97.5  44.7  55.3    11:41  48  14   2.2    176   62.5
# 803  ...   93.3  100.9  46.6  53.4    13:40  11  11  -5.8     94   47.9
# 804  ...   92.5  100.2  47.0  53.0     8:14   5   5  -3.3     28   67.9
# 805  ...   93.0  100.3  30.9  69.1    12:16  20  21   6.4    157   62.4
# 806  ...   90.3  102.3  51.6  48.4    16:05  32  16   7.7    189   56.1
# 807  ...   90.1   99.3  52.5  47.5    13:20  21  22  -0.4    238   65.1
# 808  ...   92.0  102.3  54.0  46.0    12:23  18  19   2.2    159   56.6
# 809  ...   89.6   96.0  64.5  35.5    13:36   0   6  -0.7     29   37.9
# 810  ...   91.6  100.8  58.7  41.3    19:04  32  47   3.6    334   56.0
# 811  ...   90.9  100.8  69.8  30.2    13:17   8   1   4.7     29   31.0
# 812  ...  100.0  109.5  46.2  53.8     8:22   1   1   0.9      4   25.0
# 813  ...   89.8  101.0  54.8  45.2    15:10  26  45   3.0    164   60.4
# 814  ...   95.8  111.5  46.3  53.7     9:14   4   8  -2.2     31   54.8
# 815  ...   94.4  102.3  41.5  58.5    10:21  21  14  -5.7     76   56.6
# 816  ...   93.9  104.8  35.7  64.3    17:27  26  52  -4.6    155   55.5
# 817  ...   92.3  100.4  38.1  61.9    11:36  13  11  -4.5    144   59.0
#
# [818 rows x 48 columns]

# %%
##team stats
dfteams['Abv'] = abrvs
dfteams.tail()
dfteams.to_csv('../data/teamclean.csv',index=False)
clean.to_csv('../data/playerclean.csv', index=False)
dfteams
# Out:
#                      Name  GP   W   L  OL  PTS   PTS%   GF   GA   SRS  ...  \
# 0           Boston Bruins  70  44  14  12  100  0.714  227  174  0.74  ...
# 1     Washington Capitals  69  41  20   8   90  0.652  240  215  0.41  ...
# 2     Tampa Bay Lightning  70  43  21   6   92  0.657  245  195  0.71  ...
# 3     Philadelphia Flyers  69  41  21   7   89  0.645  232  196  0.52  ...
# 4     Pittsburgh Penguins  69  40  23   6   86  0.623  224  196  0.39  ...
# 5     Carolina Hurricanes  68  38  25   5   81  0.596  222  193  0.41  ...
# 6     Toronto Maple Leafs  70  36  25   9   81  0.579  238  227  0.15  ...
# 7   Columbus Blue Jackets  70  33  22  15   81  0.579  180  187 -0.12  ...
# 8      New York Islanders  68  35  23  10   80  0.588  192  193  0.01  ...
# 9        New York Rangers  70  37  28   5   79  0.564  234  222  0.15  ...
# 10       Florida Panthers  69  35  26   8   78  0.565  231  228  0.05  ...
# 11     Montreal Canadiens  71  31  31   9   71  0.500  212  221 -0.12  ...
# 12         Buffalo Sabres  69  30  31   8   68  0.493  195  217 -0.34  ...
# 13      New Jersey Devils  69  28  29  12   68  0.493  189  230 -0.57  ...
# 14        Ottawa Senators  71  25  34  12   62  0.437  191  243 -0.76  ...
# 15      Detroit Red Wings  71  17  49   5   39  0.275  145  267 -1.70  ...
# 16        St. Louis Blues  71  42  19  10   94  0.662  225  193  0.47  ...
# 17   Vegas Golden Knights  71  39  24   8   86  0.606  227  211  0.21  ...
# 18     Colorado Avalanche  70  42  20   8   92  0.657  237  191  0.64  ...
# 19        Edmonton Oilers  71  37  25   9   83  0.585  225  217  0.09  ...
# 20           Dallas Stars  69  37  24   8   82  0.594  180  177  0.09  ...
# 21          Winnipeg Jets  71  37  28   6   80  0.563  216  203  0.17  ...
# 22         Calgary Flames  70  36  27   7   79  0.564  210  215 -0.08  ...
# 23      Vancouver Canucks  69  36  27   6   78  0.565  228  217  0.13  ...
# 24    Nashville Predators  69  35  26   8   78  0.565  215  217 -0.03  ...
# 25         Minnesota Wild  69  35  27   7   77  0.558  220  220  0.01  ...
# 26        Arizona Coyotes  70  33  29   8   74  0.529  195  187  0.11  ...
# 27     Chicago Blackhawks  70  32  30   8   72  0.514  212  218 -0.05  ...
# 28          Anaheim Ducks  71  29  33   9   67  0.472  187  226 -0.53  ...
# 29      Los Angeles Kings  70  29  35   6   64  0.457  178  212 -0.48  ...
# 30        San Jose Sharks  70  29  36   5   63  0.450  182  226 -0.62  ...
#
#      SCA  SCF%  HDF  HDA  HDF%  HDGF  HDC%  HDGA  HDCO%  Abv
# 0   1307  51.1  368  405  47.6    62  14.4    48   10.6  BOS
# 1   1459  49.2  368  447  45.2    52  12.4    47    9.5  WSH
# 2   1344  53.1  485  377  56.3    73  13.1    49   11.5  TBL
# 3   1367  51.8  428  411  51.0    52  10.8    53   11.4  PHI
# 4   1327  52.7  477  456  51.1    76  13.7    58   11.3  PIT
# 5   1316  51.5  441  405  52.1    69  13.5    60   12.9  CAR
# 6   1351  56.5  545  430  55.9    66  10.8    66   13.3  TOR
# 7   1316  51.8  432  414  51.1    77  15.1    61   12.8  CBJ
# 8   1505  48.0  397  448  47.0    60  13.1    66   12.8  NYI
# 9   1373  51.8  460  421  52.2    58  11.2    53   11.2  NYR
# 10  1301  53.8  508  401  55.9    65  11.3    56   12.3  FLA
# 11  1380  50.1  393  382  50.7    50  11.3    53   12.2  MTL
# 12  1528  51.8  490  460  51.6    69  12.3    76   14.2  BUF
# 13  1507  48.8  454  461  49.6    57  11.2    65   12.4  NJD
# 14  1633  46.2  406  545  42.7    57  12.3    70   11.4  OTT
# 15  1493  51.0  453  426  51.5    64  12.4    50   10.5  DET
# 16  1617  46.9  422  553  43.3    59  12.3    59    9.6  STL
# 17  1428  49.6  410  416  49.6    73  15.1    61   12.8  VEG
# 18  1557  48.3  463  457  50.3    61  11.6    67   12.8  COL
# 19  1404  49.7  401  481  45.5    63  13.6    63   11.6  EDM
# 20  1221  51.9  445  351  55.9    65  12.7    54   13.3  DAL
# 21  1548  47.6  465  461  50.2    58  11.1    59   11.3  WPG
# 22  1645  47.8  449  524  46.1    64  12.5    66   11.2  CGY
# 23  1380  54.2  553  434  56.0    67  10.8    65   13.0  VAN
# 24  1361  48.9  392  405  49.2    61  13.5    65   13.8  NSH
# 25  1536  45.4  361  423  46.0    53  12.8    55   11.5  MIN
# 26  1606  47.7  407  478  46.0    46  10.2    69   12.6  ARI
# 27  1506  49.7  512  448  53.3    59  10.3    63   12.3  CHI
# 28  1495  48.8  482  462  51.1    52   9.7    72   13.5  ANA
# 29  1545  49.5  504  473  51.6    66  11.6    68   12.6  LAK
# 30  1504  45.1  354  470  43.0    44  11.1    81   14.7  SJS
#
# [31 rows x 40 columns]

# %%
tostore = [clean,dfteams]
# %store tostore
# Out:
# Stored 'tostore' (list)
